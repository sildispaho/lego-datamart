# %%
import pyodbc
from datetime import datetime

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=LAPTOP-4JAFNCU9\SQLEXPRESS;"
    "DATABASE=DWH;"
    "Trusted_Connection=yes;"
)

cursor = conn.cursor()

try:
    cursor.execute("EXEC pr_Report_Info")
    conn.commit()
    print(f"Procedure executed successfully at {datetime.now()}")

except Exception as e:
    print("Error executing procedure:", e)

finally:
    cursor.close()
    conn.close()
# Out:
# Procedure executed successfully at 2025-12-17 02:30:42.600190
